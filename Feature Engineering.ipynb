# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('ESSdata_Thinkful.csv')

# %%
df.head()
# Out:
#   cntry  idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  sclmeet  sclact  \
# 0    CH   5.0     6    3.0      3.0     10.0     5.0    8.0      5.0     4.0
# 1    CH  25.0     6    6.0      5.0      7.0     5.0    9.0      3.0     2.0
# 2    CH  26.0     6    1.0      8.0      8.0     8.0    7.0      6.0     3.0
# 3    CH  28.0     6    4.0      6.0      6.0     7.0   10.0      6.0     2.0
# 4    CH  29.0     6    5.0      6.0      7.0     5.0    8.0      7.0     2.0
#
#    gndr  agea  partner
# 0   2.0  60.0      1.0
# 1   2.0  59.0      1.0
# 2   1.0  24.0      2.0
# 3   2.0  64.0      1.0
# 4   2.0  55.0      1.0

# %%
df.cntry.unique()
# Out:
# array(['CH', 'CZ', 'DE', 'ES', 'NO', 'SE'], dtype=object)

# %%
df.dtypes
# Out:
# cntry       object
# idno       float64
# year         int64
# tvtot      float64
# ppltrst    float64
# pplfair    float64
# pplhlp     float64
# happy      float64
# sclmeet    float64
# sclact     float64
# gndr       float64
# agea       float64
# partner    float64
# dtype: object

# %%
type(df.year)
# Out:
# pandas.core.series.Series

# %%
#Categorize each of the variables in the ESS dataset as categorical or continuous, 
#and if continuous as ordinal, interval, or ratio variables. Check your work with your mentor, 
#and discuss what that information might imply for feature engineering with this data.

# %%
df['Nordic'] = np.where((df['cntry'].isin(['NO', 'SE'])), 1, 0)
print(pd.crosstab(df['Nordic'], df['cntry']))
# Out:
# cntry     CH    CZ  DE    ES    NO    SE
# Nordic
# 0       1546  1316  28  2426     0     0
# 1          0     0   0     0  1462  1816

# %%
#df['Nordic'] = np.where((df['cntry'].isin(['NO', 'SE'])), 1, 0)

# %%
df['idno'] = pd.cut(df.idno,[0,10], include_lowest = True)
print(df)
# Out:
#      cntry            idno  year  tvtot  ppltrst  pplfair  pplhlp  happy  \
# 0       CH  (-0.001, 10.0]     6    3.0      3.0     10.0     5.0    8.0
# 1       CH             NaN     6    6.0      5.0      7.0     5.0    9.0
# 2       CH             NaN     6    1.0      8.0      8.0     8.0    7.0
# 3       CH             NaN     6    4.0      6.0      6.0     7.0   10.0
# 4       CH             NaN     6    5.0      6.0      7.0     5.0    8.0
# 5       CH             NaN     6    4.0      6.0      7.0     3.0    8.0
# 6       CH             NaN     6    3.0      0.0      5.0     2.0    0.0
# 7       CH             NaN     6    2.0      4.0      5.0     3.0   10.0
# 8       CH             NaN     6    2.0      8.0      8.0     8.0    9.0
# 9       CH             NaN     6    4.0      4.0      4.0     8.0    7.0
# 10      CH             NaN     6    1.0      6.0      7.0     7.0    9.0
# 11      CH             NaN     6    4.0      5.0      7.0     7.0    7.0
# ...

# %%
df['year'] = pd.cut(df.year,[6,7], include_lowest = True)
print(df)
# Out:
#      cntry            idno          year  tvtot  ppltrst  pplfair  pplhlp  \
# 0       CH  (-0.001, 10.0]  (5.999, 7.0]    3.0      3.0     10.0     5.0
# 1       CH             NaN  (5.999, 7.0]    6.0      5.0      7.0     5.0
# 2       CH             NaN  (5.999, 7.0]    1.0      8.0      8.0     8.0
# 3       CH             NaN  (5.999, 7.0]    4.0      6.0      6.0     7.0
# 4       CH             NaN  (5.999, 7.0]    5.0      6.0      7.0     5.0
# 5       CH             NaN  (5.999, 7.0]    4.0      6.0      7.0     3.0
# 6       CH             NaN  (5.999, 7.0]    3.0      0.0      5.0     2.0
# 7       CH             NaN  (5.999, 7.0]    2.0      4.0      5.0     3.0
# 8       CH             NaN  (5.999, 7.0]    2.0      8.0      8.0     8.0
# 9       CH             NaN  (5.999, 7.0]    4.0      4.0      4.0     8.0
# 10      CH             NaN  (5.999, 7.0]    1.0      6.0      7.0     7.0
# 11      CH             NaN  (5.999, 7.0]    4.0      5.0      7.0     7.0
# ...
